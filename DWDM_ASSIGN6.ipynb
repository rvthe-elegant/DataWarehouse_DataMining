# %% [markdown]
# # 20MAI0038
# # Rahul Laxman Vasanad
# # Assigment-6
# # Text Mining

# %% [markdown]
# # 1.Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # 2. Scarpping Tables from COVID19 Karanataka State Wikipedia Page

# %%
#Scrapping of first Table
wiki_url = 'https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Karnataka'


response = requests.get(wiki_url)
soup = BeautifulSoup(response.text,'html.parser')

table1 = soup.find('table',attrs={'class':'infobox'})
df = pd.read_html(str(table1))

# %%
print(df)
# Out:
# [   COVID-19 pandemic in Karnataka                   COVID-19 pandemic in Karnataka.1
# 0                         Disease                                           COVID-19
# 1                    Virus strain                                         SARS-CoV-2
# 2                        Location                                   Karnataka, India
# 3                  First outbreak                                Wuhan, Hubei, China
# 4                      Index case                                    Bengaluru Urban
# 5                    Arrival date  8 March 2020(1 year, 2 months, 1 week and 3 days)
# 6                 Confirmed cases                                       1,564,132[1]
# 7                    Active cases                                       4,051,068[1]
# 8                       Recovered                                      11,43,250 [1]
# 9                          Deaths                                         15,794 [1]
# 10                  Fatality rate                                                [1]
# 11             Government website                                 Government website
# 12  karunadu.karnataka.gov.in/hfw                      karunadu.karnataka.gov.in/hfw]

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',500)
pd.set_option('display.min_rows',100)
pd.set_option('display.max_colwidth',150)
pd.set_option('display.width',120)
pd.set_option('expand_frame_repr',True)

# %%
df = pd.read_html(str(table1))
print(df)
# Out:
# [   COVID-19 pandemic in Karnataka                   COVID-19 pandemic in Karnataka.1
# 0                         Disease                                           COVID-19
# 1                    Virus strain                                         SARS-CoV-2
# 2                        Location                                   Karnataka, India
# 3                  First outbreak                                Wuhan, Hubei, China
# 4                      Index case                                    Bengaluru Urban
# 5                    Arrival date  8 March 2020(1 year, 2 months, 1 week and 3 days)
# 6                 Confirmed cases                                       1,564,132[1]
# 7                    Active cases                                       4,051,068[1]
# 8                       Recovered                                      11,43,250 [1]
# 9                          Deaths                                         15,794 [1]
# 10                  Fatality rate                                                [1]
# 11             Government website                                 Government website
# 12  karunadu.karnataka.gov.in/hfw                      karunadu.karnataka.gov.in/hfw]

# %%
#Storing into Csv file
df[0].to_csv('covid1.csv', index=False, encoding='utf-8')

# %%
#Loading stored csv file
df = pd.read_csv("covid1.csv")
df.shape
# Out:
# (13, 2)

# %%
#Displaying th records
df.head(13)
# Out:
#    COVID-19 pandemic in Karnataka                   COVID-19 pandemic in Karnataka.1
# 0                         Disease                                           COVID-19
# 1                    Virus strain                                         SARS-CoV-2
# 2                        Location                                   Karnataka, India
# 3                  First outbreak                                Wuhan, Hubei, China
# 4                      Index case                                    Bengaluru Urban
# 5                    Arrival date  8 March 2020(1 year, 2 months, 1 week and 3 days)
# 6                 Confirmed cases                                       1,564,132[1]
# 7                    Active cases                                       4,051,068[1]
# 8                       Recovered                                      11,43,250 [1]
# 9                          Deaths                                         15,794 [1]
# 10                  Fatality rate                                                [1]
# 11             Government website                                 Government website
# 12  karunadu.karnataka.gov.in/hfw                      karunadu.karnataka.gov.in/hfw

# %%
#Scrapping Second table
response = requests.get(wiki_url)
soup = BeautifulSoup(response.text,'html.parser')

table2 = soup.find('div',attrs={'class':'barbox tright'})
df2 = pd.read_html(str(table2))

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',500)
pd.set_option('display.min_rows',100)
pd.set_option('display.max_colwidth',150)
pd.set_option('display.width',120)
pd.set_option('expand_frame_repr',True)

# %%
df2 = pd.read_html(str(table2))
print(df2)
# Out:
# [    COVID-19 cases in Karnataka, India (.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vte) Deaths Recoveries Active cases2020202020212021MarMarAprAprMayMayJunJunJulJulAugAugSepSepOctOctNovNovDecDecJanJanFebFebMarMarAprAprLast 15 daysLast 15 days  \
# 0                                                                                                                                                     Date
# 1                                                                                                                                               2020-03-11
# 2                                                                                                                                               2020-03-12
# 3                                                                                                                                               2020-03-13
# 4                                                                                                                                               2020-03-14
# 5                                                                                                                                               2020-03-15
# 6                                                                                                                                               2020-03-16
# 7                                                                                                                                               2020-03-17
# 8                                                                                                                                               2020-03-18
# 9                                                                                                                                               2020-03-19
# 10                                                                                                                                              2020-03-20
# 11                                                                                                                                              2020-03-21
# 12                                                                                                                                              2020-03-22
# 13                                                                                                                                              2020-03-23
# 14                                                                                                                                              2020-03-24
# 15                                                                                                                                              2020-03-25
# 16                                                                                                                                              2020-03-26
# 17                                                                                                                                              2020-03-27
# 18                                                                                                                                              2020-03-28
# 19                                                                                                                                              2020-03-29
# 20                                                                                                                                              2020-03-30
# 21                                                                                                                                              2020-03-31
# 22                                                                                                                                              2020-04-01
# 23                                                                                                                                              2020-04-02
# 24                                                                                                                                              2020-04-03
# 25                                                                                                                                              2020-04-04
# 26                                                                                                                                              2020-04-05
# 27                                                                                                                                              2020-04-06
# 28                                                                                                                                              2020-04-07
# 29                                                                                                                                              2020-04-08
# 30                                                                                                                                              2020-04-09
# 31                                                                                                                                              2020-04-10
# 32                                                                                                                                              2020-04-11
# 33                                                                                                                                              2020-04-12
# 34                                                                                                                                              2020-04-13
# 35                                                                                                                                              2020-04-14
# 36                                                                                                                                              2020-04-15
# 37                                                                                                                                              2020-04-16
# 38                                                                                                                                              2020-04-17
# 39                                                                                                                                              2020-04-18
# 40                                                                                                                                              2020-04-19
# ...
# 402                                                                                                                                         13,112(+0.51%)
# 403                                                                                                                                         13,190(+0.59%)
# 404                                                                                                                                         13,270(+0.61%)
# 405                                                                                                                                         13,351(+0.61%)
# 406                                                                                                                                          13,497(+1.1%)
# 407                                                                                                                                          13,646(+1.1%)
# 408                                                                                                                                         13,762(+0.85%)
# 409                                                                                                                                         13,885(+0.89%)
# 410                                                                                                                                          14,075(+1.4%)
# 411                                                                                                                                          14,283(+1.5%)
# 412                                                                                                                                            14,426(+1%)
# 413                                                                                                                                          14,627(+1.4%)
# 414                                                                                                                                          14,807(+1.2%)
# 415                                                                                                  Sources: MoHFW and karunadu.karnataka.gov.in and [1].                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ]

# %%
df2[0].to_csv('covid2.csv', index=False, encoding='utf-8')

# %%
df2 = pd.read_csv("covid2.csv")
df2.shape
# Out:
# (414, 5)

# %%
df2.tail(15)
# Out:
#            Date      Date.1 Unnamed: 2         # of cases     # of deaths
# 399  2021-04-14  2021-04-14      ​ ​ ​  1,083,647(+0.82%)  13,008(+0.52%)
# 400  2021-04-15  2021-04-15      ​ ​ ​     1,094,912(+1%)  13,046(+0.29%)
# 401  2021-04-16  2021-04-16      ​ ​ ​   1,109,650(+1.3%)  13,112(+0.51%)
# 402  2021-04-17  2021-04-17      ​ ​ ​   1,124,509(+1.3%)  13,190(+0.59%)
# 403  2021-04-18  2021-04-18      ​ ​ ​   1,141,998(+1.6%)  13,270(+0.61%)
# 404  2021-04-19  2021-04-19      ​ ​ ​   1,161,065(+1.7%)  13,351(+0.61%)
# 405  2021-04-20  2021-04-20      ​ ​ ​   1,176,850(+1.4%)   13,497(+1.1%)
# 406  2021-04-21  2021-04-21      ​ ​ ​   1,198,644(+1.9%)   13,646(+1.1%)
# 407  2021-04-22  2021-04-22      ​ ​ ​     1,222,202(+2%)  13,762(+0.85%)
# 408  2021-04-23  2021-04-23      ​ ​ ​   1,247,997(+2.1%)  13,885(+0.89%)
# 409  2021-04-24  2021-04-24      ​ ​ ​   1,274,959(+2.2%)   14,075(+1.4%)
# 410  2021-04-25  2021-04-25      ​ ​ ​   1,304,397(+2.3%)   14,283(+1.5%)
# 411  2021-04-26  2021-04-26      ​ ​ ​   1,339,201(+2.7%)     14,426(+1%)
# 412  2021-04-27  2021-04-27      ​ ​ ​   1,368,945(+2.2%)   14,627(+1.4%)
# 413  2021-04-28  2021-04-28      ​ ​ ​   1,400,775(+2.3%)   14,807(+1.2%)

# %%
#Scrapping the Third table
tables = pd.read_html(wiki_url) 
tables[3]
# Out:
#    vteCOVID-19 pandemic in Karnataka by district                                                                    \
#                                         District           Total cases            Recoveries                Deaths
#                                            Total             16,46,303             11,85,299                16,250
# 0                                      Bagalkote                 18864                 15891                   158
# 1                                        Ballari                 54921                 43389                   766
# 2                                       Belagavi                 33958                 29881                   362
# 3                                Bengaluru Rural                 31544                 22224                   242
# 4                                Bengaluru Urban                819404                517770                  6716
# 5                                          Bidar                 18921                 14885                   262
# 6                                 Chamarajanagar                 12652                  9357                   186
# 7                                Chikkaballapura                 22682                 17349                   147
# 8                                 Chikkamagaluru                 18942                 15925                   161
# 9                                    Chitradurga                 17666                 16261                    81
# 10                              Dakshina Kannada                 47831                 39188                   758
# 11                                    Davanagere                 26897                 24584                   288
# 12                                       Dharwad                 32741                 27496                   714
# 13                                         Gadag                 13216                 12238                   141
# 14                                        Hassan                 42547                 33611                   529
# 15                                        Haveri                 12892                 11732                   228
# 16                                    Kalaburagi                 42129                 32527                   484
# 17                                        Kodagu                 12523                  8235                    90
# 18                                         Kolar                 19929                 16148                   224
# 19                                        Koppal                 19626                 15280                   287
# 20                                        Mandya                 33910                 27310                   221
# 21                                        Mysuru                 84739                 68950                  1234
# 22                                       Raichur                 22925                 16546                   172
# 23                                    Ramanagara                 12130                  9475                   125
# 24                                    Shivamogga                 29378                 24579                   405
# 25                                      Tumakuru                 51700                 35114                   501
# 26                                         Udupi                 33154                 30463                   201
# 27                                Uttara Kannada                 20838                 17267                   221
# 28                                    Vijayapura                 22513                 19451                   249
# 29                                        Yadgir                 15095                 12140                    94
# 30                                   Other State                    36                    33                     3
# 31                          As of 2021-05-03[77]  As of 2021-05-03[77]  As of 2021-05-03[77]  As of 2021-05-03[77]
#
#
#             Active cases
#                 4,44,754
# 0                   2815
# 1                  10766
# 2                   3715
# 3                   9078
# 4                 294918
# 5                   3774
# 6                   3109
# 7                   5186
# 8                   2856
# 9                   1324
# 10                  7885
# 11                  2025
# 12                  4531
# 13                   837
# 14                  8407
# 15                   932
# 16                  9118
# 17                  4198
# 18                  3557
# 19                  4059
# 20                  6379
# 21                 14555
# 22                  6207
# 23                  2530
# 24                  4394
# 25                 16085
# 26                  2490
# 27                  3350
# 28                  2813
# 29                  2861
# 30                     0
# 31  As of 2021-05-03[77]

# %%
tables[3].to_csv('covid3.csv', index=False, encoding='utf-8')

# %%
df3 = pd.read_csv("covid3.csv")
df3.shape
# Out:
# (32, 5)

# %%
df3.head()
# Out:
#           District Total cases Recoveries  Deaths Active cases
# 0            Total   16,46,303  11,85,299  16,250     4,44,754
# 1        Bagalkote       18864      15891     158         2815
# 2          Ballari       54921      43389     766        10766
# 3         Belagavi       33958      29881     362         3715
# 4  Bengaluru Rural       31544      22224     242         9078

# %%
df3.tail()
# Out:
#           District Total cases Recoveries Deaths Active cases
# 27           Udupi       33154      30463    201         2490
# 28  Uttara Kannada       20838      17267    221         3350
# 29      Vijayapura       22513      19451    249         2813
# 30          Yadgir       15095      12140     94         2861
# 31     Other State          36         33      3            0
